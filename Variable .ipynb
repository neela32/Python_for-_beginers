# %%
my_dog=2

# %%
my_dog=["Sammy", "poppy"]

# %%
my_dog
# Out:
# ['Sammy', 'poppy']

# %%
print(my_dog)
# Out:
# ['Sammy', 'poppy']

# %%
my_dog=4

# %%
my_dog
# Out:
# 4

# %%
my_dog=my_dog+5

# %%
my_dog
# Out:
# 9

# %% [markdown]
# dynamic type : can cause error and plus point is easy and fast development

# %%
int=4.1

# %%
int
# Out:
# 4.1

# %%
my_income=100
rate=0.1
my_taxes=my_income *rate

# %%
my_taxes
# Out:
# 10.0
