# %%
print('fuck out')
# Out:
# fuck out

# %%
1+78 # shift + enter shortcut for running code
# Out:
# 79

# %%
#Try other platform for python coding
#repel.It
#google colab
8*5
# Out:
# 40

# %%
4%3
# Out:
# 1
