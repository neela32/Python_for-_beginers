# %% [markdown]
# String are ordered sequences : we can use indexing  and slicing
# Slicing allows you to grab a subsection of multiple characters, a "slice" of the stering.
# Syntax:  [statrt:stop:step]
# start: numerical index for the slice start
# stop:index you will go up to but not include
# step:

# %%
'hello'
# Out:
# 'hello'

# %%
"world"
# Out:
# 'world'

# %%
'this is also a string'
# Out:
# 'this is also a string'

# %%
"'I' m going on a run # mixing double and single quotes
# Out:
# "'I' m going on a run"

# %%
print('hello world')
# Out:
# hello world

# %%
print('hello \t world')
# Out:
# hello 	 world

# %%
len('hello')
# Out:
# 5

# %%
len("Amrita")
# Out:
# 6
