# %% [markdown]
# Dictionary : key: value pair

# %%
my_dict={'key1':'Value1','key2':'Value2'}

# %%
my_dict
# Out:
# {'key1': 'Value1', 'key2': 'Value2'}

# %%
my_dict['key2']
# Out:
# 'Value2'

# %%
prices_lookup={'apples':2.99, 'banana':3.99, 'Tea leave':6.99}
prices_lookup['banana']
# Out:
# 3.99

# %%
my_dict.keys()
# Out:
# dict_keys(['key1', 'key2'])

# %%
my_dict.values
# Out:
# dict_values(['Value1', 'Value2'])
