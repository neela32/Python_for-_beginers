# %%
my_list=[1,2,'Three',45,56,'Three']
print(my_list)
# Out:
# [1, 2, 'Three', 45, 56, 'Three']

# %%
sonam=my_list[2:]
print(sonam)
# Out:
# ['Three', 45, 56, 'Three']

# %%
sonam[3]="the list is mutuable unlike string"

# %%
sonam
# Out:
# ['Three', 45, 56, 'the list is mutuable unlike string']

# %%
sonam.append('LAST')# append funvtion appends at end of the list
sonam
# Out:
# ['Three', 45, 56, 'the list is mutuable unlike string', 'LAST']

# %%
poped_item=sonam.pop()# it will remove the element from end of the list

# %%
sonam
# Out:
# ['Three', 45, 56]

# %%
poped_item
# Out:
# 'the list is mutuable unlike string'

# %%
removing_item_from_list_specific_inded=sonam.pop(0)

# %%
removing_item_from_list_specific_inded
# Out:
# 45

# %%
sonam
# Out:
# [56]

# %%
sonam.append('12,13,14,15,16')

# %%
sonam
# Out:
# [56, '12,13,14,15,16']

# %%
new_list=['a','z','i','b','e']
num_list=[13,4,405,6,17,8,9,10]

# %%
new_list.sort()

# %%
new_list
# Out:
# ['a', 'b', 'e', 'i', 'z']

# %%
num_list.sort()
num_list
# Out:
# [4, 6, 8, 9, 10, 13, 17, 405]

# %% [markdown]
# num_list.reverse()

# %%
num_list.reverse()
num_list
# Out:
# [405, 17, 13, 10, 9, 8, 6, 4]
