# %%
t=(1,2,3)
my_list=[1,2,3]

# %%
type(my_list)
# Out:
# list

# %%
type(t)
# Out:
# tuple

# %%
tt=('a','a', 2,4,4)

# %%
tt.count(4)
# Out:
# 2

# %%
tt[0]='new'# not mutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 tt[0]='new'
#
# TypeError: 'tuple' object does not support item assignment
